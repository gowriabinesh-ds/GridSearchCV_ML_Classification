# %%
import pandas as pd

# %%
dataset=pd.read_csv("Social_Network_Ads.csv")

# %%
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0         True
# 1    15810944   35            20000          0         True
# 2    15668575   26            43000          0        False
# 3    15603246   27            57000          0        False
# 4    15804002   19            76000          0         True
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1        False
# 396  15706071   51            23000          1         True
# 397  15654296   50            20000          1        False
# 398  15755018   36            33000          0         True
# 399  15594041   49            36000          1        False
#
# [400 rows x 5 columns]

# %%
dataset=dataset.drop("User ID",axis=1)

# %%
dataset["Purchased"].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
indep=dataset[["Age","EstimatedSalary","Gender_Male"]]
dep=dataset["Purchased"]

# %%
indep.shape
# Out:
# (400, 3)

# %%
dep
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    0
# 399    1
# Name: Purchased, Length: 400, dtype: int64

# %%
# split into training set and test
# in regression we skip this step in gridsearch method, but in classification we do this in order to get the confusion matrix and classification report.

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
param_grid = {'kernel':['rbf', 'poly', 'sigmoid', 'linear'],
              'C':[10,100,1000], 'gamma':['auto', 'scale']}

grid = GridSearchCV(SVC(probability=True), param_grid, refit=True, verbose=3, n_jobs=-1, scoring='f1_weighted')

# fitting the model for grid search
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(estimator=SVC(probability=True), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000], 'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']},
#              scoring='f1_weighted', verbose=3)

# %%
# print best parameter after tuning
# print(grid.best_params_)
clf=grid.cv_results_
grid_predictions=grid.predict(X_test)

from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test, grid_predictions)

# print classification report
from sklearn.metrics import classification_report
clf_report=classification_report(y_test, grid_predictions)

# %%
# f1 score is one of the evaluation metrics
# sample to check f1 macro value
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,grid_predictions,average='weighted')
print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}: 0.9100355779243318

# %%
print("The confusion Matrix:\n",cm)
# Out:
# The confusion Matrix:
#  [[80  5]
#  [ 7 42]]

# %%
print("The report:\n",clf_report)
# Out:
# The report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93        85
#            1       0.89      0.86      0.88        49
#
#     accuracy                           0.91       134
#    macro avg       0.91      0.90      0.90       134
# weighted avg       0.91      0.91      0.91       134

# %%
# roc_auc score is also an evaluation metric (a scoring parametr in classification)
# if the roc_auc value is nearly 1, then the model performs well

from sklearn.metrics import roc_auc_score
roc_auc_score(y_test,grid.predict_proba(X_test)[:,1])
# Out:
# 0.9539015606242497

# %%
table=pd.DataFrame.from_dict(clf)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.013378      0.005050         0.004123        0.001007       10
# 1        0.014241      0.002402         0.004933        0.000673       10
# 2        0.008195      0.001599         0.003873        0.001049       10
# 3        0.012714      0.000991         0.003256        0.000695       10
# 4        0.011605      0.001296         0.003130        0.001084       10
# 5        0.011973      0.002120         0.002127        0.001223       10
# 6        0.007343      0.000473         0.004352        0.001094       10
# 7        0.012455      0.001106         0.003201        0.000401       10
# 8        0.012856      0.002070         0.003435        0.000479      100
# 9        0.049393      0.015764         0.003166        0.000496      100
# 10       0.006447      0.001085         0.003006        0.000895      100
# 11       0.040301      0.001705         0.003494        0.002051      100
# 12       0.012431      0.001180         0.003317        0.000760      100
# 13       0.052563      0.023244         0.002923        0.000574      100
# 14       0.007059      0.000464         0.002504        0.000631      100
# 15       0.042063      0.008872         0.002903        0.000491      100
# 16       0.040407      0.007528         0.003055        0.000601     1000
# 17       0.372371      0.110615         0.002218        0.001344     1000
# 18       0.006869      0.000653         0.002976        0.000526     1000
# 19       0.267918      0.055425         0.001826        0.001157     1000
# 20       0.038061      0.005352         0.002908        0.000663     1000
# 21       0.464245      0.163921         0.004121        0.002295     1000
# 22       0.009023      0.003102         0.002123        0.001821     1000
# 23       0.304846      0.066162         0.002313        0.001411     1000
#
#    param_gamma param_kernel  \
# 0         auto          rbf
# 1         auto         poly
# 2         auto      sigmoid
# 3         auto       linear
# 4        scale          rbf
# 5        scale         poly
# 6        scale      sigmoid
# 7        scale       linear
# 8         auto          rbf
# 9         auto         poly
# 10        auto      sigmoid
# 11        auto       linear
# 12       scale          rbf
# 13       scale         poly
# 14       scale      sigmoid
# 15       scale       linear
# 16        auto          rbf
# 17        auto         poly
# 18        auto      sigmoid
# 19        auto       linear
# 20       scale          rbf
# 21       scale         poly
# 22       scale      sigmoid
# 23       scale       linear
#
#                                                params  split0_test_score  \
# 0         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}           0.867478
# 1        {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}           0.799620
# 2     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.762677
# 3      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}           0.776290
# 4        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}           0.867478
# 5       {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}           0.799620
# 6    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.762677
# 7     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}           0.776290
# 8        {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.867478
# 9       {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.822092
# 10   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.808927
# 11    {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.776290
# 12      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.867478
# 13     {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}           0.822092
# 14  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.808927
# 15   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.776290
# 16      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}           0.826263
# 17     {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}           0.822092
# 18  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.791752
# 19   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.776290
# 20     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}           0.847141
# 21    {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}           0.822092
# 22  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...           0.808927
# 23  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.776290
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.886792           0.869709           0.944161
# 1            0.808392           0.787943           0.924528
# 2            0.738916           0.655795           0.796284
# 3            0.790949           0.698235           0.923510
# 4            0.886792           0.869709           0.944161
# 5            0.808392           0.787943           0.924528
# 6            0.738916           0.753180           0.778067
# 7            0.790949           0.698235           0.923510
# 8            0.886792           0.870362           0.944161
# 9            0.787284           0.766556           0.924528
# 10           0.714931           0.633719           0.718497
# 11           0.790949           0.698235           0.923510
# 12           0.886792           0.870362           0.944161
# 13           0.787284           0.766556           0.924528
# 14           0.714931           0.698113           0.796284
# 15           0.790949           0.698235           0.923510
# 16           0.866968           0.851527           0.925272
# 17           0.765553           0.766556           0.924528
# 18           0.714931           0.698113           0.796284
# 19           0.790949           0.698235           0.923510
# 20           0.866968           0.851527           0.925272
# 21           0.765553           0.766556           0.924528
# 22           0.714931           0.698113           0.796284
# 23           0.790949           0.698235           0.923510
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.943041         0.902236        0.034431                3
# 1            0.901744         0.844445        0.056918                7
# 2            0.766556         0.744045        0.047743               23
# 3            0.901744         0.818146        0.083619               13
# 4            0.943041         0.902236        0.034431                3
# 5            0.901744         0.844445        0.056918                7
# 6            0.766556         0.759879        0.013172               19
# 7            0.901744         0.818146        0.083619               13
# 8            0.943041         0.902367        0.034308                1
# 9            0.901744         0.840441        0.062370                9
# 10           0.766556         0.728526        0.058625               24
# 11           0.901744         0.818146        0.083619               13
# 12           0.943041         0.902367        0.034308                1
# 13           0.901744         0.840441        0.062370                9
# 14           0.766556         0.756962        0.043745               20
# 15           0.901744         0.818146        0.083619               13
# 16           0.923510         0.878708        0.039503                6
# 17           0.901744         0.836095        0.066541               11
# 18           0.766556         0.753527        0.040048               22
# 19           0.901744         0.818146        0.083619               13
# 20           0.923510         0.882884        0.034529                5
# 21           0.901744         0.836095        0.066541               11
# 22           0.766556         0.756962        0.043745               20
# 23           0.901744         0.818146        0.083619               13

# %%
age_input=float(input("Age:"))
salary_input=float(input("Salary:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
# Out:
# Age: 85
# Salary: 10000
# Sex Male 0 or 1: 0

# %%
Future_Prediction = grid.predict([[age_input,salary_input,sex_male_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[1]
